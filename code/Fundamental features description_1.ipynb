# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from pylab import mpl

# %%
data=pd.read_csv("/Users/macbookpro/Downloads/cars1.csv" )
data
# Out:
#          make model  priceUSD  year     condition  mileage(kilometers)  \
# 0       mazda     2      5500  2008  with mileage             162000.0
# 1       mazda     2      5350  2009  with mileage             120000.0
# 2       mazda     2      7000  2009  with mileage              61000.0
# 3       mazda     2      3300  2003  with mileage             265000.0
# 4       mazda     2      5200  2008  with mileage              97183.0
# ...       ...   ...       ...   ...           ...                  ...
# 55936  lancia  zeta      3650  2000  with mileage             290000.0
# 55937  lancia  zeta      4100  1999  with mileage             340000.0
# 55938  lancia  zeta      3600  1997  with mileage             354000.0
# 55939  lancia  zeta      3000  1997  with mileage             350000.0
# 55940  lancia  zeta      2950  1996  with mileage                  3.0
#
#       fuel_type  volume(cm3)     color transmission         drive_unit segment
# ...

# %% [markdown]
# # pie of column(condition)

# %%
group1={}
for i in data['condition']:
    group[i]=group.get(i,0)+1
print(group)
# Out:
# {'with mileage': 109988, 'with damage': 1020, 'for parts': 874}

# %%
key1=[]
for h in group.keys():
    key1.append(h)
    value1=[]
    for m in group.values():
        value1.append(m)
print(key1)
print(value1)
# Out:
# ['with mileage', 'with damage', 'for parts']
# [109988, 1020, 874]

# %%
fracs1=[x for x in key1]
explode1=[x*0.5 for x in range(len(key1))]
plt.pie(value1,labels=key1,explode=explode,autopct='%0.1f%%',startangle=180,labeldistance=1.5,pctdistance=0.5, center=(3, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of condition',fontsize=18)
plt.show()

# %%
group2={}
for i in data['drive_unit']:
    group2[i]=group2.get(i,0)+1
print(group2)
# Out:
# {'front-wheel drive': 39216, 'rear drive': 6999, 'all-wheel drive': 6046, 'part-time four-wheel drive': 3680}

# %%
key2=[]
for h in group2.keys():
    key2.append(h)
    value2=[]
    for m in group2.values():
        value2.append(m)
print(key2)
print(value2)
# Out:
# ['front-wheel drive', 'rear drive', 'all-wheel drive', 'part-time four-wheel drive']
# [39216, 6999, 6046, 3680]

# %%
fracs2=[x for x in key2]
#explode2=[x*0.5 for x in range(len(key2))]
plt.pie(value2,labels=key2,autopct='%0.1f%%',labeldistance=1.3,pctdistance=0.6, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of  drive_unit',fontsize=15)
plt.show()

# %%
group3={}
for i in data['transmission']:
    group3[i]=group3.get(i,0)+1
print(group3)
# Out:
# {'mechanics': 35803, 'auto': 20138}

# %%
key3=[]
for h in group3.keys():
    key3.append(h)
    value3=[]
    for m in group3.values():
        value3.append(m)
print(key3)
print(value3)
# Out:
# ['mechanics', 'auto']
# [35803, 20138]

# %%
fracs3=[x for x in key3]
#explode2=[x*0.5 for x in range(len(key2))]
plt.pie(value3,labels=key3,autopct='%0.1f%%',labeldistance=0.5,pctdistance=0.7, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of transmission',fontsize=15)
plt.show()

# %%
group4={}
for i in data['fuel_type']:
    group4[i]=group4.get(i,0)+1
print(group4)
# Out:
# {'petrol': 36205, 'diesel': 19689, 'electrocar': 47}

# %%
key4=[]
for h in group4.keys():
    key4.append(h)
    value4=[]
    for m in group4.values():
        value4.append(m)
print(key4)
print(value4)
# Out:
# ['petrol', 'diesel', 'electrocar']
# [36205, 19689, 47]

# %%
fracs4=[x for x in key4]
explode2=[x*0.07 for x in range(len(key4))]
plt.pie(value4,explode=explode2,labels=key4,autopct='%0.1f%%',labeldistance=1.1,pctdistance=0.7, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of fuel_type ',fontsize=15)
plt.show()

# %%
group5={}
for i in data['color']:
    group5[i]=group5.get(i,0)+1
print(group5)
# Out:
# {'burgundy': 2014, 'black': 12336, 'silver': 10024, 'white': 5271, 'gray': 5780, 'blue': 8031, 'other': 3371, 'purple': 623, 'red': 2721, 'green': 3878, 'brown': 1346, 'yellow': 313, 'orange': 233}

# %%
key5=[]
for h in group5.keys():
    key5.append(h)
    value5=[]
    for m in group5.values():
        value5.append(m)
print(key5)
print(value5)
# Out:
# ['burgundy', 'black', 'silver', 'white', 'gray', 'blue', 'other', 'purple', 'red', 'green', 'brown', 'yellow', 'orange']
# [2014, 12336, 10024, 5271, 5780, 8031, 3371, 623, 2721, 3878, 1346, 313, 233]

# %%
fracs5=[x for x in key5]
explode5=[0,0,0,0,0,0,0,0.3,0,0,0,0.2,0.5]
plt.pie(value5,explode=explode5,labels=key5,autopct='%0.1f%%',colors=['red','Orange','y','green','c','salmon','purple','violet', 'lightskyblue', 'goldenrod', 'greenyellow', 'hotpink','turquoise'],labeldistance=1.1,pctdistance=0.7, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of color  ',fontsize=15)
plt.show()

# %%
group6={}
for i in data['segment']:
    group6[i]=group6.get(i,0)+1
print(group6)
# Out:
# {'B': 4614, 'C': 11279, 'M': 7368, 'D': 12771, 'E': 7307, 'A': 514, 'J': 10240, 'S': 871, 'F': 977}

# %%
key6=[]
for h in group6.keys():
    key6.append(h)
    value6=[]
    for m in group6.values():
        value6.append(m)
print(key6)
print(value6)
# Out:
# ['B', 'C', 'M', 'D', 'E', 'A', 'J', 'S', 'F']
# [4614, 11279, 7368, 12771, 7307, 514, 10240, 871, 977]

# %%
fracs6=[x for x in key6]
explode6=[0,0,0,0,0,0.2,0,0.1,0.1]
plt.pie(value6,explode=explode6,labels=key6,autopct='%0.1f%%',colors=['red','Orange','yellow','green','c','hotpink','purple','pink','dodgerblue'],labeldistance=1.1,,pctdistance=0.7, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of segment ',fontsize=15)
plt.show()

# %%
group7={}
for i in data['year']:
    group7[i]=group7.get(i,0)+1
print(group7)
 
key7=[]
for h in group7.keys():
    key7.append(h)
    value7=[]
    for m in group7.values():
        value7.append(m)
print(key7)
print(value7)



fracs7=[x for x in key7]
explode7=[x*0.0001 for x in range(len(key7))]
plt.pie(value7,explode=explode7,labels=key7,autopct='%0.1f%%',colors=['red','Orange','yellow','green','c','hotpink','purple','pink','dodgerblue'],labeldistance=2.3,pctdistance=1, center=(2, 3))
plt.axis('equal')
plt.legend(bbox_to_anchor=(1,0.8),shadow=True,fontsize=10)
plt.title('The composition of segment ',fontsize=15)
plt.show()
# Out:
# {2008: 3165, 2009: 2187, 2003: 2092, 2005: 1851, 2010: 2588, 2006: 2170, 2012: 1549, 2004: 1973, 2007: 2678, 2014: 1744, 2011: 2115, 2013: 1605, 2016: 1417, 2018: 566, 2002: 2359, 2015: 1982, 2017: 621, 1989: 489, 1988: 423, 1986: 359, 1995: 1379, 1991: 812, 1990: 536, 1992: 832, 1994: 1131, 1993: 1055, 1997: 2441, 1996: 1855, 1998: 2806, 1964: 8, 1966: 10, 1962: 8, 1965: 6, 1963: 6, 1969: 7, 1970: 7, 1958: 4, 1960: 5, 1968: 14, 1959: 5, 1961: 7, 1957: 5, 1967: 6, 1987: 353, 1982: 75, 1984: 189, 1974: 9, 1976: 17, 1983: 121, 1978: 24, 1979: 35, 1981: 34, 1973: 6, 1977: 12, 1972: 7, 1985: 231, 1980: 43, 2001: 2609, 2000: 2395, 1999: 2647, 1948: 1, 1952: 3, 1951: 1, 1956: 5, 1954: 4, 1971: 1, 1955: 5, 1953: 1, 1975: 13, 1910: 1, 2019: 213, 1950: 2, 1949: 1, 1942: 1, 1936: 1, 1933: 1, 1938: 1, 1945: 1}
# ...
